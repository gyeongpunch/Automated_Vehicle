# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
image = cv2.imread('./test1.png', cv2.IMREAD_GRAYSCALE)
image = image/255.0

# %%
model = tf.keras.models.load_model('mnist_cnn.h5')
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/xk/p8swjkpn6tv63h79zlvj87k40000gn/T/ipykernel_82355/3191993643.py", line 1, in <module>
#     model = tf.keras.models.load_model('mnist_cnn.h5')
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/tensorflow_core/python/keras/saving/save.py", line 143, in load_model
#     return hdf5_format.load_model_from_hdf5(filepath, custom_objects, compile)
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/tensorflow_core/python/keras/saving/hdf5_format.py", line 160, in load_model_from_hdf5
#     model_config = json.loads(model_config.decode('utf-8'))
# AttributeError: 'str' object has no attribute 'decode'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'AttributeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/tensorflow/__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 967, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 677, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/tensorflow_core/contrib/__init__.py", line 39, in <module>
#     from tensorflow.contrib import compiler
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/tensorflow_core/contrib/compiler/__init__.py", line 21, in <module>
#     from tensorflow.contrib.compiler import jit
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/tensorflow_core/contrib/compiler/__init__.py", line 22, in <module>
#     from tensorflow.contrib.compiler import xla
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/tensorflow_core/contrib/compiler/xla.py", line 22, in <module>
#     from tensorflow.python.estimator import model_fn as model_fn_lib
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/tensorflow_core/python/estimator/model_fn.py", line 26, in <module>
#     from tensorflow_estimator.python.estimator import model_fn
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/tensorflow_estimator/__init__.py", line 10, in <module>
#     from tensorflow_estimator._api.v1 import estimator
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/tensorflow_estimator/_api/v1/estimator/__init__.py", line 10, in <module>
#     from tensorflow_estimator._api.v1.estimator import experimental
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/tensorflow_estimator/_api/v1/estimator/experimental/__init__.py", line 10, in <module>
#     from tensorflow_estimator.python.estimator.canned.dnn import dnn_logit_fn_builder
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/canned/dnn.py", line 27, in <module>
#     from tensorflow_estimator.python.estimator import estimator
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/estimator.py", line 36, in <module>
#     from tensorflow.python.profiler import trace
# ImportError: cannot import name 'trace' from 'tensorflow.python.profiler' (/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/tensorflow_core/python/profiler/__init__.py)
# Traceback (most recent call last):
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/xk/p8swjkpn6tv63h79zlvj87k40000gn/T/ipykernel_82355/3191993643.py", line 1, in <module>
#     model = tf.keras.models.load_model('mnist_cnn.h5')
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/tensorflow_core/python/keras/saving/save.py", line 143, in load_model
#     return hdf5_format.load_model_from_hdf5(filepath, custom_objects, compile)
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/tensorflow_core/python/keras/saving/hdf5_format.py", line 160, in load_model_from_hdf5
#     model_config = json.loads(model_config.decode('utf-8'))
# AttributeError: 'str' object has no attribute 'decode'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'AttributeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/tensorflow/__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
# Traceback (most recent call last):
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/xk/p8swjkpn6tv63h79zlvj87k40000gn/T/ipykernel_82355/3191993643.py", line 1, in <module>
#     model = tf.keras.models.load_model('mnist_cnn.h5')
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/tensorflow_core/python/keras/saving/save.py", line 143, in load_model
#     return hdf5_format.load_model_from_hdf5(filepath, custom_objects, compile)
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/tensorflow_core/python/keras/saving/hdf5_format.py", line 160, in load_model_from_hdf5
#     model_config = json.loads(model_config.decode('utf-8'))
# AttributeError: 'str' object has no attribute 'decode'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'AttributeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2960, in _run_cell
#     return runner(coro)
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3186, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3396, in run_ast_nodes
#     self.showtraceback()
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1143, in structured_traceback
#     chained_exceptions_tb_offset)
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/site-packages/tensorflow/__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "/Users/hangyeonghun/opt/anaconda3/envs/study/lib/python3.7/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'

# %%
test_image = np.expand_dims(image, axis = 0)
predict = model.predict(test_image)
print('predict ',predict, np.argmax(predict, axis=1))

# %%
plt.imshow(test_image[0], cmap='Greys')
plt.show()
